# %%
a = "hello, world!"#shift enter누르면 실행
print(a)
# Out:
# hello, world!

# %%
1+3.14159
# Out:
# 4.14159

# %%
1-3.14159
# Out:
# -2.14159

# %%
3 * 7
# Out:
# 21

# %%
3.14/2
# Out:
# 1.57

# %%
#거듭제곱
10**2
# Out:
# 100

# %%
3**3
# Out:
# 27

# %%
5**4
# Out:
# 625

# %%
3*10**2, 3*1e2 #둘은 같은 값이다
# Out:
# (300, 300.0)

# %%
#변수지정
a = 2.5
pi = 3.14
r = 2

# %%
pi*r**2
# Out:
# 12.56

# %%
pi+r,pi-r,pi*r,pi/r
# Out:
# (5.140000000000001, 1.1400000000000001, 6.28, 1.57)

# %%
r == 2
pi == 3.14
# Out:
# True

# %%
3**4, pow(3,4) #power 제곱을 뜻하는거 
#이렇게 쓸 수 있음
# Out:
#   File "<ipython-input-39-4a2b862aa24e>", line 2
#     이렇게 쓸 수 있음
#         ^
# SyntaxError: invalid syntax

# %%
#위쪽으로 생기는거 a
#지우는거 dd
#만드는거 b
#m은 셀을 마크다운으로 하는거
#문서로 사용하는 창
#해제는 y
#help창 참고

# %%
#변수지정
a+b

# %% [markdown]
# 조건문/반복문
#
# if A,x
# else if B,y
# else z

# %%
x = 5.2

# %%
if x<5:
    print("x is less than five")
elif x<10 :
    print("x is five.")
else : 
    print("x is larger than five")
# Out:
# x is five.

# %% [markdown]
# while/for

# %%
x = 5

# %%
s = 0

# %%
while(x>0) :
    s = s+x
    x = x-1
    print(x,s)
# Out:
# 4 5
# 3 9
# 2 12
# 1 14
# 0 15

# %%
x = 100
i, s = 0,0
while(i<x) :
    i = i+1
    s= s+i**2
s
# Out:
# 338350

# %% [markdown]
# for

# %%
v = [1,2,3,4,5] #리스트
s = 0
for i in v:
    s = s+i
    print(s)
# Out:
# 1
# 3
# 6
# 10
# 15

# %%
x = 5
i,s = 0,0
while (i<x):
    i = i+1
    s = s+i
    print(s)
# Out:
# 1
# 3
# 6
# 10
# 15
