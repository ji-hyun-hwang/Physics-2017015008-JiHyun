# %%
r = [0.5, 2.5, 4.5, 4.5]
f = [0.5, 0.5, 0.5, 0.51]

a = 0
b = -1
for i in f:
    a = 0
    b += 1
    while a < 10:
        a += 1
        i = r[b]*i*(1-i)
        print(a, "번째 반복된값:", i)
# Out:
# 1 번째 반복된값: 0.125
# 2 번째 반복된값: 0.0546875
# 3 번째 반복된값: 0.025848388671875
# 4 번째 반복된값: 0.012590124737471342
# 5 번째 반복된값: 0.006215806748283127
# 6 번째 반복된값: 0.0030885852473755623
# 7 번째 반복된값: 0.0015395229442726282
# 8 번째 반복된값: 0.0007685764066883431
# 9 번째 반복된값: 0.00038399284849771257
# 10 번째 반복된값: 0.0001919226989950076
# 1 번째 반복된값: 0.625
# 2 번째 반복된값: 0.5859375
# 3 번째 반복된값: 0.606536865234375
# 4 번째 반복된값: 0.5966247408650815
# 5 번째 반복된값: 0.6016591486318896
# 6 번째 반복된값: 0.5991635437485985
# 7 번째 반복된값: 0.6004164789780495
# 8 번째 반복된값: 0.5997913268741273
# 9 번째 반복된값: 0.6001042277017528
# 10 번째 반복된값: 0.599947858990589
# 1 번째 반복된값: 1.125
# 2 번째 반복된값: -0.6328125
# 3 번째 반복된값: -4.649688720703125
# 4 번째 반복된값: -118.21182264061645
# 5 번째 반복된값: -63415.11075595729
# 6 번째 반복된값: -18096928592.854885
# 7 번째 반복된값: -1.4737447103084353e+21
# 8 번째 반복된값: -9.773655620229423e+42
# 9 번째 반복된값: -4.298595488227898e+86
# 10 번째 반복된값: -8.315065427135959e+173
# 1 번째 반복된값: 1.12455
# 2 번째 반복된값: -0.6302821612499996
# ...
